# %% [markdown]
# # CALCOLARE IL FATTORIALE DI UN NUMERO

# %%
#Chiedere all'utente di inserire un numero intero positivo
print("Ciao, attraverso questo programma puoi calcolare il fattoriale di qualsiasi numero che desideri sapere")
numero=int(input("Quindi, inserisci il numero intero positivo che desideri calcolare: "))
fattoriale=1
if fattoriale<0:
    print("non è possibile calcolare il fattoriale di un numero negativo ")
elif fattoriale==0:
    print("il fattoriale di 0 è sempre 1")
else:
    for numero in range(1,numero+1):
        fattoriale*=numero#il simbolo *= svolge due compiti in uno: fa la somma e riassegna il valore della varia
print(f"Il fattoriale di {numero} è {fattoriale}")#l'f string serve per creare per l'appunto una stringa ma senza dover chiudere tutte le volte le parentesi e le virgolette ma mettendo semplicemente delle parentesi graffe
# Out:
# Ciao, attraverso questo programma puoi calcolare il fattoriale di qualsiasi numero che desideri sapere
# Quindi, inserisci il numero intero positivo che desideri calcolare: 80
# Il fattoriale di 80 è 71569457046263802294811533723186532165584657342365752577109445058227039255480148842668944867280814080000000000000000000

# %% [markdown]
# # LA SOMMA DEI PRIMI N NUMERI PARI

# %%
#Chiedere all'utente di inserire un numero intero positivo N
print("Ciao, attraverso questo programma puoi calcolare la somma dei numeri pari di qualsiasi numero che desideri sapere")
N=int(input("Quindi, inserisci il numero intero positivo che desideri calcolare: "))
#Inizializzare la somma a zero
somma=0
#Calcolare la somma dei primi N numero pari
for numero in range(2,2*N+1,2):#il primo valore è sempre 2, il secondo valore è la moltiplicazione del valore di N per 2 e aggiungendo poi 1 al risultato, il terzo valore è sempre 2.
    somma+=numero#il simbolo += svolge due compiti in uno: fa la somma e riassegna il valore della variabile
#Stampare la somma
print(f"La somma dei primi {N} numeri pari è {somma}")
# Out:
# Ciao, attraverso questo programma puoi calcolare la somma dei numeri pari di qualsiasi numero che desideri sapere
# Quindi, inserisci il numero intero positivo che desideri calcolare: 3
# La somma dei primi 3 numeri pari è 12

# %% [markdown]
# # CREARE UNA LISTA DEI NUMERI PARI

# %%
print("Ciao, attraverso questo programma puoi creare una lista dei numeri pari fino a qualsiasi numero che desideri sapere")
N=int(input("Quindi, inserisci il numero intero positivo da cui desideri creare la lista: "))
lista=[]
for numero in range(2,2*N+1,2):
    lista.append(numero)
print(lista)
# Out:
# Ciao, attraverso questo programma puoi creare una lista dei numeri pari fino a qualsiasi numero che desideri sapere
# Quindi, inserisci il numero intero positivo da cui desideri creare la lista: 4
# [2, 4, 6, 8]

# %% [markdown]
# # CONTEGGIO DELLE VOCALI IN UNA FRASE E CONVERSIONE DELLA FRASE IN MAIUSCOLO

# %%
#Chiedere all'utente di inserire una frase o una frase o una parola
print("Ciao, questo programma permette di contare le vocali presenti in una frase")
frase=input("Quindi, inserisci una frase o una parola: ").lower()#converte tutto in minuscolo per semplificare il conteggio e non dover limitare l'utente a scrivere una determinata cosa
conteggiodellevocali=0
vocali="aàáâäeèéêëiìíîïoòóôöuùúûü"
#Iniziallizare il contatore o iteratore
for carattere in frase:
    if carattere in vocali:
        conteggiodellevocali+=1
print(f"Nella frase/parola che hai appena scritto ci sono {conteggiodellevocali} vocali")
# Out:
# Ciao, questo programma permette di contare le vocali presenti in una frase
# Quindi, inserisci una frase o una parola: tavolo
# Nella frase/parola che hai appena scritto ci sono 3 vocali

# %% [markdown]
# # CALCOLO STATISTICO DELLA NATALITÀ

# %%
#Iniziallizare la popolazione e gli anni
print("Ciao, questo programma permette di simulare un calcolo statistico della natalità dal passato fino ad oggi attraverso dei dati matematici da inserire")
popolazione=int(input("Scrivi il numero della popolazione totale nel tuo paese in questo momento: "))
anni=int(input("Inserisci l'anno corrente: "))
tassodinatalita=float(input("Inserisci il tasso di natalità del tuo paese in questo momento: "))#vuol dire che l'input è un float cioè un numero con la virgola (si usa il punto) e non intero come è per l'int
tassodimortalita=float(input("Inserisci il tasso di mortalità del tuo paese in questo momento: "))
#Iniziallizare il contatore o iteratore
for anno in range(anni):
    nascite=(popolazione*tassodinatalita)/100
    decessi=(popolazione*tassodimortalita)/100
    popolazione+=(nascite-decessi)
    print(f"Nell'anno {anno+1} la popolazione è stata di {int(popolazione)} abitanti")#si usa l'anno +1 così parte dall'anno dopo quello inserito dall'utente invece di quello inserito veramente dall'utente
if nascite>decessi:
    print("Dai dati statistici raccolti si può dedurre che nel corso degli anni ci sia stato un innalzamento demografico")
elif nascite==decessi:
    print("Dai dati statistici raccolti si può dedurre che nel corso degli anni il numero dei decessi non è cambiato rispetto a quello delle nascite, quindi c'è stata una crescita zero")
else:
    print("Dai dati statistici raccolti si può dedurre che nel corso degli anni ci sia stato un calo demografico")
print("Simulazione calcolo statistico della natalità dal passato fino ad oggi completato corretamente")
# Out:
# Ciao, questo programma permette di simulare un calcolo statistico della natalità dal passato fino ad oggi attraverso dei dati matematici da inserire
# Scrivi il numero della popolazione totale nel tuo paese in questo momento: 2000
# Inserisci l'anno corrente: 2023
# Inserisci il tasso di natalità del tuo paese in questo momento: 20
# Inserisci il tasso di mortalità del tuo paese in questo momento: 10
# Nell'anno 1 la popolazione è stata di 2200 abitanti
# Nell'anno 2 la popolazione è stata di 2420 abitanti
# Nell'anno 3 la popolazione è stata di 2662 abitanti
# Nell'anno 4 la popolazione è stata di 2928 abitanti
# Nell'anno 5 la popolazione è stata di 3221 abitanti
# Nell'anno 6 la popolazione è stata di 3543 abitanti
# Nell'anno 7 la popolazione è stata di 3897 abitanti
# Nell'anno 8 la popolazione è stata di 4287 abitanti
# Nell'anno 9 la popolazione è stata di 4715 abitanti
# Nell'anno 10 la popolazione è stata di 5187 abitanti
# Nell'anno 11 la popolazione è stata di 5706 abitanti
# Nell'anno 12 la popolazione è stata di 6276 abitanti
# Nell'anno 13 la popolazione è stata di 6904 abitanti
# Nell'anno 14 la popolazione è stata di 7594 abitanti
# Nell'anno 15 la popolazione è stata di 8354 abitanti
# Nell'anno 16 la popolazione è stata di 9189 abitanti
# Nell'anno 17 la popolazione è stata di 10108 abitanti
# Nell'anno 18 la popolazione è stata di 11119 abitanti
# Nell'anno 19 la popolazione è stata di 12231 abitanti
# Nell'anno 20 la popolazione è stata di 13454 abitanti
# Nell'anno 21 la popolazione è stata di 14800 abitanti
# Nell'anno 22 la popolazione è stata di 16280 abitanti
# Nell'anno 23 la popolazione è stata di 17908 abitanti
# Nell'anno 24 la popolazione è stata di 19699 abitanti
# Nell'anno 25 la popolazione è stata di 21669 abitanti
# Nell'anno 26 la popolazione è stata di 23836 abitanti
# Nell'anno 27 la popolazione è stata di 26219 abitanti
# Nell'anno 28 la popolazione è stata di 28841 abitanti
# Nell'anno 29 la popolazione è stata di 31726 abitanti
# Nell'anno 30 la popolazione è stata di 34898 abitanti
# Nell'anno 31 la popolazione è stata di 38388 abitanti
# Nell'anno 32 la popolazione è stata di 42227 abitanti
# Nell'anno 33 la popolazione è stata di 46450 abitanti
# Nell'anno 34 la popolazione è stata di 51095 abitanti
# Nell'anno 35 la popolazione è stata di 56204 abitanti
# Nell'anno 36 la popolazione è stata di 61825 abitanti
# Nell'anno 37 la popolazione è stata di 68007 abitanti
# Nell'anno 38 la popolazione è stata di 74808 abitanti
# Nell'anno 39 la popolazione è stata di 82289 abitanti
# Nell'anno 40 la popolazione è stata di 90518 abitanti
# Nell'anno 41 la popolazione è stata di 99570 abitanti
# Nell'anno 42 la popolazione è stata di 109527 abitanti
# Nell'anno 43 la popolazione è stata di 120480 abitanti
# Nell'anno 44 la popolazione è stata di 132528 abitanti
# Nell'anno 45 la popolazione è stata di 145780 abitanti
# Nell'anno 46 la popolazione è stata di 160359 abitanti
# Nell'anno 47 la popolazione è stata di 176394 abitanti
# Nell'anno 48 la popolazione è stata di 194034 abitanti
# Nell'anno 49 la popolazione è stata di 213437 abitanti
# Nell'anno 50 la popolazione è stata di 234781 abitanti
# Nell'anno 51 la popolazione è stata di 258259 abitanti
# Nell'anno 52 la popolazione è stata di 284085 abitanti
# Nell'anno 53 la popolazione è stata di 312494 abitanti
# Nell'anno 54 la popolazione è stata di 343743 abitanti
# Nell'anno 55 la popolazione è stata di 378118 abitanti
# Nell'anno 56 la popolazione è stata di 415930 abitanti
# Nell'anno 57 la popolazione è stata di 457523 abitanti
# Nell'anno 58 la popolazione è stata di 503275 abitanti
# Nell'anno 59 la popolazione è stata di 553602 abitanti
# Nell'anno 60 la popolazione è stata di 608963 abitanti
# Nell'anno 61 la popolazione è stata di 669859 abitanti
# Nell'anno 62 la popolazione è stata di 736845 abitanti
# Nell'anno 63 la popolazione è stata di 810530 abitanti
# Nell'anno 64 la popolazione è stata di 891583 abitanti
# Nell'anno 65 la popolazione è stata di 980741 abitanti
# Nell'anno 66 la popolazione è stata di 1078815 abitanti
# Nell'anno 67 la popolazione è stata di 1186697 abitanti
# Nell'anno 68 la popolazione è stata di 1305366 abitanti
# Nell'anno 69 la popolazione è stata di 1435903 abitanti
# Nell'anno 70 la popolazione è stata di 1579493 abitanti
# Nell'anno 71 la popolazione è stata di 1737443 abitanti
# Nell'anno 72 la popolazione è stata di 1911187 abitanti
# Nell'anno 73 la popolazione è stata di 2102306 abitanti
# Nell'anno 74 la popolazione è stata di 2312537 abitanti
# Nell'anno 75 la popolazione è stata di 2543790 abitanti
# Nell'anno 76 la popolazione è stata di 2798169 abitanti
# Nell'anno 77 la popolazione è stata di 3077986 abitanti
# Nell'anno 78 la popolazione è stata di 3385785 abitanti
# Nell'anno 79 la popolazione è stata di 3724364 abitanti
# Nell'anno 80 la popolazione è stata di 4096800 abitanti
# Nell'anno 81 la popolazione è stata di 4506480 abitanti
# Nell'anno 82 la popolazione è stata di 4957128 abitanti
# Nell'anno 83 la popolazione è stata di 5452841 abitanti
# Nell'anno 84 la popolazione è stata di 5998125 abitanti
# Nell'anno 85 la popolazione è stata di 6597938 abitanti
# Nell'anno 86 la popolazione è stata di 7257731 abitanti
# Nell'anno 87 la popolazione è stata di 7983505 abitanti
# Nell'anno 88 la popolazione è stata di 8781855 abitanti
# Nell'anno 89 la popolazione è stata di 9660041 abitanti
# Nell'anno 90 la popolazione è stata di 10626045 abitanti
# Nell'anno 91 la popolazione è stata di 11688649 abitanti
# Nell'anno 92 la popolazione è stata di 12857514 abitanti
# Nell'anno 93 la popolazione è stata di 14143266 abitanti
# Nell'anno 94 la popolazione è stata di 15557592 abitanti
# Nell'anno 95 la popolazione è stata di 17113352 abitanti
# Nell'anno 96 la popolazione è stata di 18824687 abitanti
# Nell'anno 97 la popolazione è stata di 20707156 abitanti
# Nell'anno 98 la popolazione è stata di 22777871 abitanti
# Nell'anno 99 la popolazione è stata di 25055658 abitanti
# Nell'anno 100 la popolazione è stata di 27561224 abitanti
# Nell'anno 101 la popolazione è stata di 30317347 abitanti
# Nell'anno 102 la popolazione è stata di 33349081 abitanti
# Nell'anno 103 la popolazione è stata di 36683990 abitanti
# Nell'anno 104 la popolazione è stata di 40352389 abitanti
# Nell'anno 105 la popolazione è stata di 44387627 abitanti
# Nell'anno 106 la popolazione è stata di 48826390 abitanti
# Nell'anno 107 la popolazione è stata di 53709029 abitanti
# Nell'anno 108 la popolazione è stata di 59079932 abitanti
# Nell'anno 109 la popolazione è stata di 64987926 abitanti
# Nell'anno 110 la popolazione è stata di 71486718 abitanti
# Nell'anno 111 la popolazione è stata di 78635390 abitanti
# Nell'anno 112 la popolazione è stata di 86498929 abitanti
# Nell'anno 113 la popolazione è stata di 95148822 abitanti
# Nell'anno 114 la popolazione è stata di 104663704 abitanti
# Nell'anno 115 la popolazione è stata di 115130075 abitanti
# Nell'anno 116 la popolazione è stata di 126643082 abitanti
# Nell'anno 117 la popolazione è stata di 139307391 abitanti
# Nell'anno 118 la popolazione è stata di 153238130 abitanti
# Nell'anno 119 la popolazione è stata di 168561943 abitanti
# Nell'anno 120 la popolazione è stata di 185418137 abitanti
# Nell'anno 121 la popolazione è stata di 203959951 abitanti
# Nell'anno 122 la popolazione è stata di 224355946 abitanti
# Nell'anno 123 la popolazione è stata di 246791541 abitanti
# Nell'anno 124 la popolazione è stata di 271470695 abitanti
# Nell'anno 125 la popolazione è stata di 298617764 abitanti
# Nell'anno 126 la popolazione è stata di 328479541 abitanti
# Nell'anno 127 la popolazione è stata di 361327495 abitanti
# Nell'anno 128 la popolazione è stata di 397460245 abitanti
# Nell'anno 129 la popolazione è stata di 437206269 abitanti
# Nell'anno 130 la popolazione è stata di 480926896 abitanti
# Nell'anno 131 la popolazione è stata di 529019586 abitanti
# Nell'anno 132 la popolazione è stata di 581921544 abitanti
# Nell'anno 133 la popolazione è stata di 640113699 abitanti
# Nell'anno 134 la popolazione è stata di 704125069 abitanti
# Nell'anno 135 la popolazione è stata di 774537576 abitanti
# Nell'anno 136 la popolazione è stata di 851991333 abitanti
# Nell'anno 137 la popolazione è stata di 937190466 abitanti
# Nell'anno 138 la popolazione è stata di 1030909513 abitanti
# Nell'anno 139 la popolazione è stata di 1134000465 abitanti
# Nell'anno 140 la popolazione è stata di 1247400511 abitanti
# Nell'anno 141 la popolazione è stata di 1372140562 abitanti
# Nell'anno 142 la popolazione è stata di 1509354618 abitanti
# Nell'anno 143 la popolazione è stata di 1660290080 abitanti
# Nell'anno 144 la popolazione è stata di 1826319088 abitanti
# Nell'anno 145 la popolazione è stata di 2008950997 abitanti
# Nell'anno 146 la popolazione è stata di 2209846097 abitanti
# Nell'anno 147 la popolazione è stata di 2430830707 abitanti
# Nell'anno 148 la popolazione è stata di 2673913778 abitanti
# Nell'anno 149 la popolazione è stata di 2941305155 abitanti
# Nell'anno 150 la popolazione è stata di 3235435671 abitanti
# Nell'anno 151 la popolazione è stata di 3558979238 abitanti
# Nell'anno 152 la popolazione è stata di 3914877162 abitanti
# Nell'anno 153 la popolazione è stata di 4306364878 abitanti
# Nell'anno 154 la popolazione è stata di 4737001366 abitanti
# Nell'anno 155 la popolazione è stata di 5210701503 abitanti
# Nell'anno 156 la popolazione è stata di 5731771653 abitanti
# Nell'anno 157 la popolazione è stata di 6304948819 abitanti
# Nell'anno 158 la popolazione è stata di 6935443701 abitanti
# Nell'anno 159 la popolazione è stata di 7628988071 abitanti
# Nell'anno 160 la popolazione è stata di 8391886878 abitanti
# Nell'anno 161 la popolazione è stata di 9231075566 abitanti
# Nell'anno 162 la popolazione è stata di 10154183122 abitanti
# Nell'anno 163 la popolazione è stata di 11169601434 abitanti
# Nell'anno 164 la popolazione è stata di 12286561578 abitanti
# Nell'anno 165 la popolazione è stata di 13515217736 abitanti
# Nell'anno 166 la popolazione è stata di 14866739509 abitanti
# Nell'anno 167 la popolazione è stata di 16353413460 abitanti
# Nell'anno 168 la popolazione è stata di 17988754806 abitanti
# Nell'anno 169 la popolazione è stata di 19787630287 abitanti
# Nell'anno 170 la popolazione è stata di 21766393316 abitanti
# Nell'anno 171 la popolazione è stata di 23943032648 abitanti
# Nell'anno 172 la popolazione è stata di 26337335912 abitanti
# Nell'anno 173 la popolazione è stata di 28971069504 abitanti
# Nell'anno 174 la popolazione è stata di 31868176454 abitanti
# Nell'anno 175 la popolazione è stata di 35054994100 abitanti
# Nell'anno 176 la popolazione è stata di 38560493510 abitanti
# Nell'anno 177 la popolazione è stata di 42416542861 abitanti
# Nell'anno 178 la popolazione è stata di 46658197147 abitanti
# Nell'anno 179 la popolazione è stata di 51324016861 abitanti
# Nell'anno 180 la popolazione è stata di 56456418548 abitanti
# Nell'anno 181 la popolazione è stata di 62102060402 abitanti
# Nell'anno 182 la popolazione è stata di 68312266443 abitanti
# Nell'anno 183 la popolazione è stata di 75143493087 abitanti
# Nell'anno 184 la popolazione è stata di 82657842396 abitanti
# Nell'anno 185 la popolazione è stata di 90923626635 abitanti
# Nell'anno 186 la popolazione è stata di 100015989299 abitanti
# Nell'anno 187 la popolazione è stata di 110017588229 abitanti
# Nell'anno 188 la popolazione è stata di 121019347052 abitanti
# Nell'anno 189 la popolazione è stata di 133121281757 abitanti
# Nell'anno 190 la popolazione è stata di 146433409933 abitanti
# Nell'anno 191 la popolazione è stata di 161076750926 abitanti
# Nell'anno 192 la popolazione è stata di 177184426019 abitanti
# Nell'anno 193 la popolazione è stata di 194902868621 abitanti
# Nell'anno 194 la popolazione è stata di 214393155483 abitanti
# Nell'anno 195 la popolazione è stata di 235832471031 abitanti
# Nell'anno 196 la popolazione è stata di 259415718134 abitanti
# Nell'anno 197 la popolazione è stata di 285357289948 abitanti
# Nell'anno 198 la popolazione è stata di 313893018942 abitanti
# Nell'anno 199 la popolazione è stata di 345282320837 abitanti
# Nell'anno 200 la popolazione è stata di 379810552920 abitanti
# Nell'anno 201 la popolazione è stata di 417791608213 abitanti
# Nell'anno 202 la popolazione è stata di 459570769034 abitanti
# Nell'anno 203 la popolazione è stata di 505527845937 abitanti
# Nell'anno 204 la popolazione è stata di 556080630531 abitanti
# Nell'anno 205 la popolazione è stata di 611688693584 abitanti
# Nell'anno 206 la popolazione è stata di 672857562943 abitanti
# Nell'anno 207 la popolazione è stata di 740143319237 abitanti
# Nell'anno 208 la popolazione è stata di 814157651161 abitanti
# Nell'anno 209 la popolazione è stata di 895573416277 abitanti
# Nell'anno 210 la popolazione è stata di 985130757905 abitanti
# Nell'anno 211 la popolazione è stata di 1083643833695 abitanti
# Nell'anno 212 la popolazione è stata di 1192008217065 abitanti
# Nell'anno 213 la popolazione è stata di 1311209038771 abitanti
# Nell'anno 214 la popolazione è stata di 1442329942648 abitanti
# Nell'anno 215 la popolazione è stata di 1586562936913 abitanti
# Nell'anno 216 la popolazione è stata di 1745219230605 abitanti
# Nell'anno 217 la popolazione è stata di 1919741153665 abitanti
# Nell'anno 218 la popolazione è stata di 2111715269032 abitanti
# Nell'anno 219 la popolazione è stata di 2322886795935 abitanti
# Nell'anno 220 la popolazione è stata di 2555175475528 abitanti
# Nell'anno 221 la popolazione è stata di 2810693023081 abitanti
# Nell'anno 222 la popolazione è stata di 3091762325389 abitanti
# Nell'anno 223 la popolazione è stata di 3400938557928 abitanti
# Nell'anno 224 la popolazione è stata di 3741032413721 abitanti
# Nell'anno 225 la popolazione è stata di 4115135655093 abitanti
# Nell'anno 226 la popolazione è stata di 4526649220603 abitanti
# Nell'anno 227 la popolazione è stata di 4979314142663 abitanti
# Nell'anno 228 la popolazione è stata di 5477245556930 abitanti
# Nell'anno 229 la popolazione è stata di 6024970112623 abitanti
# Nell'anno 230 la popolazione è stata di 6627467123885 abitanti
# Nell'anno 231 la popolazione è stata di 7290213836273 abitanti
# Nell'anno 232 la popolazione è stata di 8019235219901 abitanti
# Nell'anno 233 la popolazione è stata di 8821158741891 abitanti
# Nell'anno 234 la popolazione è stata di 9703274616080 abitanti
# Nell'anno 235 la popolazione è stata di 10673602077688 abitanti
# Nell'anno 236 la popolazione è stata di 11740962285457 abitanti
# Nell'anno 237 la popolazione è stata di 12915058514003 abitanti
# Nell'anno 238 la popolazione è stata di 14206564365403 abitanti
# Nell'anno 239 la popolazione è stata di 15627220801943 abitanti
# Nell'anno 240 la popolazione è stata di 17189942882138 abitanti
# Nell'anno 241 la popolazione è stata di 18908937170352 abitanti
# Nell'anno 242 la popolazione è stata di 20799830887387 abitanti
# Nell'anno 243 la popolazione è stata di 22879813976126 abitanti
# Nell'anno 244 la popolazione è stata di 25167795373738 abitanti
# Nell'anno 245 la popolazione è stata di 27684574911112 abitanti
# Nell'anno 246 la popolazione è stata di 30453032402223 abitanti
# Nell'anno 247 la popolazione è stata di 33498335642446 abitanti
# Nell'anno 248 la popolazione è stata di 36848169206690 abitanti
# Nell'anno 249 la popolazione è stata di 40532986127359 abitanti
# Nell'anno 250 la popolazione è stata di 44586284740095 abitanti
# Nell'anno 251 la popolazione è stata di 49044913214105 abitanti
# Nell'anno 252 la popolazione è stata di 53949404535516 abitanti
# Nell'anno 253 la popolazione è stata di 59344344989067 abitanti
# Nell'anno 254 la popolazione è stata di 65278779487974 abitanti
# Nell'anno 255 la popolazione è stata di 71806657436771 abitanti
# Nell'anno 256 la popolazione è stata di 78987323180449 abitanti
# Nell'anno 257 la popolazione è stata di 86886055498493 abitanti
# Nell'anno 258 la popolazione è stata di 95574661048343 abitanti
# Nell'anno 259 la popolazione è stata di 105132127153177 abitanti
# Nell'anno 260 la popolazione è stata di 115645339868495 abitanti
# Nell'anno 261 la popolazione è stata di 127209873855345 abitanti
# Nell'anno 262 la popolazione è stata di 139930861240879 abitanti
# Nell'anno 263 la popolazione è stata di 153923947364967 abitanti
# Nell'anno 264 la popolazione è stata di 169316342101464 abitanti
# Nell'anno 265 la popolazione è stata di 186247976311610 abitanti
# Nell'anno 266 la popolazione è stata di 204872773942771 abitanti
# Nell'anno 267 la popolazione è stata di 225360051337048 abitanti
# Nell'anno 268 la popolazione è stata di 247896056470753 abitanti
# Nell'anno 269 la popolazione è stata di 272685662117829 abitanti
# Nell'anno 270 la popolazione è stata di 299954228329612 abitanti
# Nell'anno 271 la popolazione è stata di 329949651162573 abitanti
# Nell'anno 272 la popolazione è stata di 362944616278830 abitanti
# Nell'anno 273 la popolazione è stata di 399239077906713 abitanti
# Nell'anno 274 la popolazione è stata di 439162985697384 abitanti
# Nell'anno 275 la popolazione è stata di 483079284267123 abitanti
# Nell'anno 276 la popolazione è stata di 531387212693835 abitanti
# Nell'anno 277 la popolazione è stata di 584525933963219 abitanti
# Nell'anno 278 la popolazione è stata di 642978527359541 abitanti
# Nell'anno 279 la popolazione è stata di 707276380095495 abitanti
# Nell'anno 280 la popolazione è stata di 778004018105044 abitanti
# Nell'anno 281 la popolazione è stata di 855804419915549 abitanti
# Nell'anno 282 la popolazione è stata di 941384861907104 abitanti
# Nell'anno 283 la popolazione è stata di 1035523348097814 abitanti
# Nell'anno 284 la popolazione è stata di 1139075682907596 abitanti
# Nell'anno 285 la popolazione è stata di 1252983251198355 abitanti
# Nell'anno 286 la popolazione è stata di 1378281576318191 abitanti
# Nell'anno 287 la popolazione è stata di 1516109733950010 abitanti
# Nell'anno 288 la popolazione è stata di 1667720707345011 abitanti
# Nell'anno 289 la popolazione è stata di 1834492778079512 abitanti
# Nell'anno 290 la popolazione è stata di 2017942055887463 abitanti
# Nell'anno 291 la popolazione è stata di 2219736261476209 abitanti
# Nell'anno 292 la popolazione è stata di 2441709887623830 abitanti
# Nell'anno 293 la popolazione è stata di 2685880876386213 abitanti
# Nell'anno 294 la popolazione è stata di 2954468964024835 abitanti
# Nell'anno 295 la popolazione è stata di 3249915860427318 abitanti
# Nell'anno 296 la popolazione è stata di 3574907446470050 abitanti
# Nell'anno 297 la popolazione è stata di 3932398191117055 abitanti
# Nell'anno 298 la popolazione è stata di 4325638010228761 abitanti
# Nell'anno 299 la popolazione è stata di 4758201811251637 abitanti
# Nell'anno 300 la popolazione è stata di 5234021992376801 abitanti
# Nell'anno 301 la popolazione è stata di 5757424191614481 abitanti
# Nell'anno 302 la popolazione è stata di 6333166610775929 abitanti
# Nell'anno 303 la popolazione è stata di 6966483271853522 abitanti
# Nell'anno 304 la popolazione è stata di 7663131599038874 abitanti
# Nell'anno 305 la popolazione è stata di 8429444758942761 abitanti
# Nell'anno 306 la popolazione è stata di 9272389234837038 abitanti
# Nell'anno 307 la popolazione è stata di 10199628158320742 abitanti
# Nell'anno 308 la popolazione è stata di 11219590974152816 abitanti
# Nell'anno 309 la popolazione è stata di 12341550071568098 abitanti
# Nell'anno 310 la popolazione è stata di 13575705078724908 abitanti
# Nell'anno 311 la popolazione è stata di 14933275586597400 abitanti
# Nell'anno 312 la popolazione è stata di 16426603145257140 abitanti
# Nell'anno 313 la popolazione è stata di 18069263459782856 abitanti
# Nell'anno 314 la popolazione è stata di 19876189805761140 abitanti
# Nell'anno 315 la popolazione è stata di 21863808786337256 abitanti
# Nell'anno 316 la popolazione è stata di 24050189664970980 abitanti
# Nell'anno 317 la popolazione è stata di 26455208631468080 abitanti
# Nell'anno 318 la popolazione è stata di 29100729494614888 abitanti
# Nell'anno 319 la popolazione è stata di 32010802444076376 abitanti
# Nell'anno 320 la popolazione è stata di 35211882688484016 abitanti
# Nell'anno 321 la popolazione è stata di 38733070957332416 abitanti
# Nell'anno 322 la popolazione è stata di 42606378053065656 abitanti
# Nell'anno 323 la popolazione è stata di 46867015858372224 abitanti
# Nell'anno 324 la popolazione è stata di 51553717444209448 abitanti
# Nell'anno 325 la popolazione è stata di 56709089188630392 abitanti
# Nell'anno 326 la popolazione è stata di 62379998107493432 abitanti
# Nell'anno 327 la popolazione è stata di 68617997918242776 abitanti
# Nell'anno 328 la popolazione è stata di 75479797710067056 abitanti
# Nell'anno 329 la popolazione è stata di 83027777481073760 abitanti
# Nell'anno 330 la popolazione è stata di 91330555229181136 abitanti
# Nell'anno 331 la popolazione è stata di 100463610752099248 abitanti
# Nell'anno 332 la popolazione è stata di 110509971827309168 abitanti
# Nell'anno 333 la popolazione è stata di 121560969010040080 abitanti
# Nell'anno 334 la popolazione è stata di 133717065911044096 abitanti
# Nell'anno 335 la popolazione è stata di 147088772502148512 abitanti
# Nell'anno 336 la popolazione è stata di 161797649752363360 abitanti
# Nell'anno 337 la popolazione è stata di 177977414727599680 abitanti
# Nell'anno 338 la popolazione è stata di 195775156200359648 abitanti
# Nell'anno 339 la popolazione è stata di 215352671820395616 abitanti
# Nell'anno 340 la popolazione è stata di 236887939002435168 abitanti
# Nell'anno 341 la popolazione è stata di 260576732902678688 abitanti
# Nell'anno 342 la popolazione è stata di 286634406192946560 abitanti
# Nell'anno 343 la popolazione è stata di 315297846812241216 abitanti
# Nell'anno 344 la popolazione è stata di 346827631493465344 abitanti
# Nell'anno 345 la popolazione è stata di 381510394642811904 abitanti
# Nell'anno 346 la popolazione è stata di 419661434107093120 abitanti
# Nell'anno 347 la popolazione è stata di 461627577517802432 abitanti
# Nell'anno 348 la popolazione è stata di 507790335269582656 abitanti
# Nell'anno 349 la popolazione è stata di 558569368796540928 abitanti
# Nell'anno 350 la popolazione è stata di 614426305676195072 abitanti
# Nell'anno 351 la popolazione è stata di 675868936243814528 abitanti
# Nell'anno 352 la popolazione è stata di 743455829868195968 abitanti
# Nell'anno 353 la popolazione è stata di 817801412855015552 abitanti
# Nell'anno 354 la popolazione è stata di 899581554140517120 abitanti
# Nell'anno 355 la popolazione è stata di 989539709554568832 abitanti
# Nell'anno 356 la popolazione è stata di 1088493680510025728 abitanti
# Nell'anno 357 la popolazione è stata di 1197343048561028352 abitanti
# Nell'anno 358 la popolazione è stata di 1317077353417131264 abitanti
# Nell'anno 359 la popolazione è stata di 1448785088758844416 abitanti
# Nell'anno 360 la popolazione è stata di 1593663597634728960 abitanti
# Nell'anno 361 la popolazione è stata di 1753029957398201856 abitanti
# Nell'anno 362 la popolazione è stata di 1928332953138022144 abitanti
# Nell'anno 363 la popolazione è stata di 2121166248451824384 abitanti
# Nell'anno 364 la popolazione è stata di 2333282873297006592 abitanti
# Nell'anno 365 la popolazione è stata di 2566611160626707456 abitanti
# Nell'anno 366 la popolazione è stata di 2823272276689378304 abitanti
# Nell'anno 367 la popolazione è stata di 3105599504358316032 abitanti
# Nell'anno 368 la popolazione è stata di 3416159454794147840 abitanti
# Nell'anno 369 la popolazione è stata di 3757775400273562624 abitanti
# Nell'anno 370 la popolazione è stata di 4133552940300918784 abitanti
# Nell'anno 371 la popolazione è stata di 4546908234331010560 abitanti
# Nell'anno 372 la popolazione è stata di 5001599057764111360 abitanti
# Nell'anno 373 la popolazione è stata di 5501758963540523008 abitanti
# Nell'anno 374 la popolazione è stata di 6051934859894575104 abitanti
# Nell'anno 375 la popolazione è stata di 6657128345884033024 abitanti
# Nell'anno 376 la popolazione è stata di 7322841180472436736 abitanti
# Nell'anno 377 la popolazione è stata di 8055125298519680000 abitanti
# Nell'anno 378 la popolazione è stata di 8860637828371648512 abitanti
# Nell'anno 379 la popolazione è stata di 9746701611208812544 abitanti
# Nell'anno 380 la popolazione è stata di 10721371772329693184 abitanti
# Nell'anno 381 la popolazione è stata di 11793508949562662912 abitanti
# Nell'anno 382 la popolazione è stata di 12972859844518928384 abitanti
# Nell'anno 383 la popolazione è stata di 14270145828970821632 abitanti
# Nell'anno 384 la popolazione è stata di 15697160411867904000 abitanti
# Nell'anno 385 la popolazione è stata di 17266876453054693376 abitanti
# Nell'anno 386 la popolazione è stata di 18993564098360164352 abitanti
# Nell'anno 387 la popolazione è stata di 20892920508196179968 abitanti
# Nell'anno 388 la popolazione è stata di 22982212559015796736 abitanti
# Nell'anno 389 la popolazione è stata di 25280433814917378048 abitanti
# Nell'anno 390 la popolazione è stata di 27808477196409114624 abitanti
# Nell'anno 391 la popolazione è stata di 30589324916050026496 abitanti
# Nell'anno 392 la popolazione è stata di 33648257407655030784 abitanti
# Nell'anno 393 la popolazione è stata di 37013083148420530176 abitanti
# Nell'anno 394 la popolazione è stata di 40714391463262584832 abitanti
# Nell'anno 395 la popolazione è stata di 44785830609588846592 abitanti
# Nell'anno 396 la popolazione è stata di 49264413670547734528 abitanti
# Nell'anno 397 la popolazione è stata di 54190855037602504704 abitanti
# Nell'anno 398 la popolazione è stata di 59609940541362757632 abitanti
# Nell'anno 399 la popolazione è stata di 65570934595499032576 abitanti
# Nell'anno 400 la popolazione è stata di 72128028055048937472 abitanti
# Nell'anno 401 la popolazione è stata di 79340830860553830400 abitanti
# Nell'anno 402 la popolazione è stata di 87274913946609221632 abitanti
# Nell'anno 403 la popolazione è stata di 96002405341270147072 abitanti
# Nell'anno 404 la popolazione è stata di 105602645875397165056 abitanti
# Nell'anno 405 la popolazione è stata di 116162910462936875008 abitanti
# Nell'anno 406 la popolazione è stata di 127779201509230559232 abitanti
# Nell'anno 407 la popolazione è stata di 140557121660153610240 abitanti
# Nell'anno 408 la popolazione è stata di 154612833826168963072 abitanti
# Nell'anno 409 la popolazione è stata di 170074117208785846272 abitanti
# Nell'anno 410 la popolazione è stata di 187081528929664434176 abitanti
# Nell'anno 411 la popolazione è stata di 205789681822630871040 abitanti
# Nell'anno 412 la popolazione è stata di 226368650004893958144 abitanti
# Nell'anno 413 la popolazione è stata di 249005515005383344128 abitanti
# Nell'anno 414 la popolazione è stata di 273906066505921691648 abitanti
# Nell'anno 415 la popolazione è stata di 301296673156513857536 abitanti
# Nell'anno 416 la popolazione è stata di 331426340472165236736 abitanti
# Nell'anno 417 la popolazione è stata di 364568974519381786624 abitanti
# Nell'anno 418 la popolazione è stata di 401025871971319939072 abitanti
# Nell'anno 419 la popolazione è stata di 441128459168451919872 abitanti
# Nell'anno 420 la popolazione è stata di 485241305085297098752 abitanti
# Nell'anno 421 la popolazione è stata di 533765435593826828288 abitanti
# Nell'anno 422 la popolazione è stata di 587141979153209491456 abitanti
# Nell'anno 423 la popolazione è stata di 645856177068530466816 abitanti
# Nell'anno 424 la popolazione è stata di 710441794775383539712 abitanti
# Nell'anno 425 la popolazione è stata di 781485974252921946112 abitanti
# Nell'anno 426 la popolazione è stata di 859634571678214127616 abitanti
# Nell'anno 427 la popolazione è stata di 945598028846035501056 abitanti
# Nell'anno 428 la popolazione è stata di 1040157831730639011840 abitanti
# Nell'anno 429 la popolazione è stata di 1144173614903702847488 abitanti
# Nell'anno 430 la popolazione è stata di 1258590976394073210880 abitanti
# Nell'anno 431 la popolazione è stata di 1384450074033480531968 abitanti
# Nell'anno 432 la popolazione è stata di 1522895081436828663808 abitanti
# Nell'anno 433 la popolazione è stata di 1675184589580511477760 abitanti
# Nell'anno 434 la popolazione è stata di 1842703048538562494464 abitanti
# Nell'anno 435 la popolazione è stata di 2026973353392418586624 abitanti
# Nell'anno 436 la popolazione è stata di 2229670688731660550144 abitanti
# Nell'anno 437 la popolazione è stata di 2452637757604826710016 abitanti
# Nell'anno 438 la popolazione è stata di 2697901533365309276160 abitanti
# Nell'anno 439 la popolazione è stata di 2967691686701840203776 abitanti
# Nell'anno 440 la popolazione è stata di 3264460855372024381440 abitanti
# Nell'anno 441 la popolazione è stata di 3590906940909226557440 abitanti
# Nell'anno 442 la popolazione è stata di 3949997635000149213184 abitanti
# Nell'anno 443 la popolazione è stata di 4344997398500163977216 abitanti
# Nell'anno 444 la popolazione è stata di 4779497138350180007936 abitanti
# Nell'anno 445 la popolazione è stata di 5257446852185198428160 abitanti
# Nell'anno 446 la popolazione è stata di 5783191537403718270976 abitanti
# Nell'anno 447 la popolazione è stata di 6361510691144089993216 abitanti
# Nell'anno 448 la popolazione è stata di 6997661760258498887680 abitanti
# Nell'anno 449 la popolazione è stata di 7697427936284348776448 abitanti
# Nell'anno 450 la popolazione è stata di 8467170729912783863808 abitanti
# Nell'anno 451 la popolazione è stata di 9313887802904061935616 abitanti
# Nell'anno 452 la popolazione è stata di 10245276583194469072896 abitanti
# Nell'anno 453 la popolazione è stata di 11269804241513915351040 abitanti
# Nell'anno 454 la popolazione è stata di 12396784665665306886144 abitanti
# Nell'anno 455 la popolazione è stata di 13636463132231837155328 abitanti
# Nell'anno 456 la popolazione è stata di 15000109445455020032000 abitanti
# Nell'anno 457 la popolazione è stata di 16500120390000523083776 abitanti
# Nell'anno 458 la popolazione è stata di 18150132429000575811584 abitanti
# Nell'anno 459 la popolazione è stata di 19965145671900631924736 abitanti
# Nell'anno 460 la popolazione è stata di 21961660239090695536640 abitanti
# Nell'anno 461 la popolazione è stata di 24157826262999767187456 abitanti
# Nell'anno 462 la popolazione è stata di 26573608889299746422784 abitanti
# Nell'anno 463 la popolazione è stata di 29230969778229722742784 abitanti
# Nell'anno 464 la popolazione è stata di 32154066756052696694784 abitanti
# Nell'anno 465 la popolazione è stata di 35369473431657965944832 abitanti
# Nell'anno 466 la popolazione è stata di 38906420774823763378176 abitanti
# Nell'anno 467 la popolazione è stata di 42797062852306142232576 abitanti
# Nell'anno 468 la popolazione è stata di 47076769137536758972416 abitanti
# Nell'anno 469 la popolazione è stata di 51784446051290433191936 abitanti
# Nell'anno 470 la popolazione è stata di 56962890656419474833408 abitanti
# Nell'anno 471 la popolazione è stata di 62659179722061421477888 abitanti
# Nell'anno 472 la popolazione è stata di 68925097694267562786816 abitanti
# Nell'anno 473 la popolazione è stata di 75817607463694321582080 abitanti
# Nell'anno 474 la popolazione è stata di 83399368210063762128896 abitanti
# Nell'anno 475 la popolazione è stata di 91739305031070145052672 abitanti
# Nell'anno 476 la popolazione è stata di 100913235534177156202496 abitanti
# Nell'anno 477 la popolazione è stata di 111004559087594878533632 abitanti
# Nell'anno 478 la popolazione è stata di 122105014996354363031552 abitanti
# Nell'anno 479 la popolazione è stata di 134315516495989804367872 abitanti
# Nell'anno 480 la popolazione è stata di 147747068145588781449216 abitanti
# Nell'anno 481 la popolazione è stata di 162521774960147657916416 abitanti
# Nell'anno 482 la popolazione è stata di 178773952456162430418944 abitanti
# Nell'anno 483 la popolazione è stata di 196651347701778683527168 abitanti
# Nell'anno 484 la popolazione è stata di 216316482471956572012544 abitanti
# Nell'anno 485 la popolazione è stata di 237948130719152222502912 abitanti
# Nell'anno 486 la popolazione è stata di 261742943791067441397760 abitanti
# Nell'anno 487 la popolazione è stata di 287917238170174202314752 abitanti
# Nell'anno 488 la popolazione è stata di 316708961987191602413568 abitanti
# Nell'anno 489 la popolazione è stata di 348379858185910749233152 abitanti
# Nell'anno 490 la popolazione è stata di 383217844004501804023808 abitanti
# Nell'anno 491 la popolazione è stata di 421539628404952004558848 abitanti
# Nell'anno 492 la popolazione è stata di 463693591245447191592960 abitanti
# Nell'anno 493 la popolazione è stata di 510062950369991877197824 abitanti
# Nell'anno 494 la popolazione è stata di 561069245406991091761152 abitanti
# Nell'anno 495 la popolazione è stata di 617176169947690247913472 abitanti
# Nell'anno 496 la popolazione è stata di 678893786942459219017728 abitanti
# Nell'anno 497 la popolazione è stata di 746783165636705194606592 abitanti
# Nell'anno 498 la popolazione è stata di 821461482200375727489024 abitanti
# Nell'anno 499 la popolazione è stata di 903607630420413327081472 abitanti
# Nell'anno 500 la popolazione è stata di 993968393462454673211392 abitanti
# Nell'anno 501 la popolazione è stata di 1093365232808700086845440 abitanti
# Nell'anno 502 la popolazione è stata di 1202701756089570162638848 abitanti
# Nell'anno 503 la popolazione è stata di 1322971931698527098372096 abitanti
# Nell'anno 504 la popolazione è stata di 1455269124868379781365760 abitanti
# Nell'anno 505 la popolazione è stata di 1600796037355217625284608 abitanti
# Nell'anno 506 la popolazione è stata di 1760875641090739441500160 abitanti
# Nell'anno 507 la popolazione è stata di 1936963205199813251432448 abitanti
# Nell'anno 508 la popolazione è stata di 2130659525719794630262784 abitanti
# Nell'anno 509 la popolazione è stata di 2343725478291774254350336 abitanti
# Nell'anno 510 la popolazione è stata di 2578098026120951787159552 abitanti
# Nell'anno 511 la popolazione è stata di 2835907828733047180623872 abitanti
# Nell'anno 512 la popolazione è stata di 3119498611606352113434624 abitanti
# Nell'anno 513 la popolazione è stata di 3431448472766987485839360 abitanti
# Nell'anno 514 la popolazione è stata di 3774593320043686502858752 abitanti
# Nell'anno 515 la popolazione è stata di 4152052652048054831022080 abitanti
# Nell'anno 516 la popolazione è stata di 4567257917252860314124288 abitanti
# Nell'anno 517 la popolazione è stata di 5023983708978146130788352 abitanti
# Nell'anno 518 la popolazione è stata di 5526382079875960958615552 abitanti
# Nell'anno 519 la popolazione è stata di 6079020287863556732354560 abitanti
# Nell'anno 520 la popolazione è stata di 6686922316649911868719104 abitanti
# Nell'anno 521 la popolazione è stata di 7355614548314903485087744 abitanti
# Nell'anno 522 la popolazione è stata di 8091176003146393189351424 abitanti
# Nell'anno 523 la popolazione è stata di 8900293603461032937783296 abitanti
# Nell'anno 524 la popolazione è stata di 9790322963807135802064896 abitanti
# Nell'anno 525 la popolazione è stata di 10769355260187848952774656 abitanti
# Nell'anno 526 la popolazione è stata di 11846290786206634492297216 abitanti
# Nell'anno 527 la popolazione è stata di 13030919864827297512030208 abitanti
# Nell'anno 528 la popolazione è stata di 14334011851310027048484864 abitanti
# Nell'anno 529 la popolazione è stata di 15767413036441030182830080 abitanti
# Nell'anno 530 la popolazione è stata di 17344154340085133201113088 abitanti
# Nell'anno 531 la popolazione è stata di 19078569774093647380217856 abitanti
# Nell'anno 532 la popolazione è stata di 20986426751503013836226560 abitanti
# Nell'anno 533 la popolazione è stata di 23085069426653313072365568 abitanti
# Nell'anno 534 la popolazione è stata di 25393576369318645238595584 abitanti
# Nell'anno 535 la popolazione è stata di 27932934006250508044468224 abitanti
# Nell'anno 536 la popolazione è stata di 30726227406875559278411776 abitanti
# Nell'anno 537 la popolazione è stata di 33798850147563116924239872 abitanti
# Nell'anno 538 la popolazione è stata di 37178735162319429905154048 abitanti
# Nell'anno 539 la popolazione è stata di 40896608678551369459695616 abitanti
# Nell'anno 540 la popolazione è stata di 44986269546406503828684800 abitanti
# Nell'anno 541 la popolazione è stata di 49484896501047154211553280 abitanti
# Nell'anno 542 la popolazione è stata di 54433386151151873927675904 abitanti
# Nell'anno 543 la popolazione è stata di 59876724766267059602456576 abitanti
# Nell'anno 544 la popolazione è stata di 65864397242893767280689152 abitanti
# Nell'anno 545 la popolazione è stata di 72450836967183147444731904 abitanti
# Nell'anno 546 la popolazione è stata di 79695920663901469061152768 abitanti
# Nell'anno 547 la popolazione è stata di 87665512730291621121228800 abitanti
# Nell'anno 548 la popolazione è stata di 96432064003320774643417088 abitanti
# Nell'anno 549 la popolazione è stata di 106075270403652848671784960 abitanti
# Nell'anno 550 la popolazione è stata di 116682797444018133538963456 abitanti
# Nell'anno 551 la popolazione è stata di 128351077188419948610846720 abitanti
# Nell'anno 552 la popolazione è stata di 141186184907261943471931392 abitanti
# Nell'anno 553 la popolazione è stata di 155304803397988132665163776 abitanti
# Nell'anno 554 la popolazione è stata di 170835283737786956239601664 abitanti
# Nell'anno 555 la popolazione è stata di 187918812111565658735509504 abitanti
# Nell'anno 556 la popolazione è stata di 206710693322722214301138944 abitanti
# Nell'anno 557 la popolazione è stata di 227381762654994425423331328 abitanti
# Nell'anno 558 la popolazione è stata di 250119938920493864529690624 abitanti
# Nell'anno 559 la popolazione è stata di 275131932812543240674738176 abitanti
# Nell'anno 560 la popolazione è stata di 302645126093797575050133504 abitanti
# Nell'anno 561 la popolazione è stata di 332909638703177339427094528 abitanti
# Nell'anno 562 la popolazione è stata di 366200602573495052753960960 abitanti
# Nell'anno 563 la popolazione è stata di 402820662830844558029357056 abitanti
# Nell'anno 564 la popolazione è stata di 443102729113929041320083456 abitanti
# Nell'anno 565 la popolazione è stata di 487413002025321972939882496 abitanti
# Nell'anno 566 la popolazione è stata di 536154302227854197721661440 abitanti
# Nell'anno 567 la popolazione è stata di 589769732450639583134089216 abitanti
# Nell'anno 568 la popolazione è stata di 648746705695703500215812096 abitanti
# Nell'anno 569 la popolazione è stata di 713621376265273877725184000 abitanti
# Nell'anno 570 la popolazione è stata di 784983513891801196778225664 abitanti
# Nell'anno 571 la popolazione è stata di 863481865280981288968257536 abitanti
# Nell'anno 572 la popolazione è stata di 949830051809079376633397248 abitanti
# Nell'anno 573 la popolazione è stata di 1044813056989987328040632320 abitanti
# Nell'anno 574 la popolazione è stata di 1149294362688986060844695552 abitanti
# Nell'anno 575 la popolazione è stata di 1264223798957884721904746496 abitanti
# Nell'anno 576 la popolazione è stata di 1390646178853673221583011840 abitanti
# Nell'anno 577 la popolazione è stata di 1529710796739040406302359552 abitanti
# Nell'anno 578 la popolazione è stata di 1682681876412944501908176896 abitanti
# Nell'anno 579 la popolazione è stata di 1850950064054238979586785280 abitanti
# Nell'anno 580 la popolazione è stata di 2036045070459662877545463808 abitanti
# Nell'anno 581 la popolazione è stata di 2239649577505629247763382272 abitanti
# Nell'anno 582 la popolazione è stata di 2463614535256192227515301888 abitanti
# Nell'anno 583 la popolazione è stata di 2709975988781811532730204160 abitanti
# Nell'anno 584 la popolazione è stata di 2980973587659992686003224576 abitanti
# Nell'anno 585 la popolazione è stata di 3279070946425991844652384256 abitanti
# Nell'anno 586 la popolazione è stata di 3606978041068590919166459904 abitanti
# Nell'anno 587 la popolazione è stata di 3967675845175450121034268672 abitanti
# Nell'anno 588 la popolazione è stata di 4364443429692994913235369984 abitanti
# Nell'anno 589 la popolazione è stata di 4800887772662294239632162816 abitanti
# Nell'anno 590 la popolazione è stata di 5280976549928523553644216320 abitanti
# Nell'anno 591 la popolazione è stata di 5809074204921375909008637952 abitanti
# Nell'anno 592 la popolazione è stata di 6389981625413513829762990080 abitanti
# Nell'anno 593 la popolazione è stata di 7028979787954864662983475200 abitanti
# Nell'anno 594 la popolazione è stata di 7731877766750351129281822720 abitanti
# Nell'anno 595 la popolazione è stata di 8505065543425386791965818880 abitanti
# Nell'anno 596 la popolazione è stata di 9355572097767925471162400768 abitanti
# Nell'anno 597 la popolazione è stata di 10291129307544717138669338624 abitanti
# Nell'anno 598 la popolazione è stata di 11320242238299188412731621376 abitanti
# Nell'anno 599 la popolazione è stata di 12452266462129106594297806848 abitanti
# Nell'anno 600 la popolazione è stata di 13697493108342018573141540864 abitanti
# Nell'anno 601 la popolazione è stata di 15067242419176219990651043840 abitanti
# Nell'anno 602 la popolazione è stata di 16573966661093843089227776000 abitanti
# Nell'anno 603 la popolazione è stata di 18231363327203227398150553600 abitanti
# Nell'anno 604 la popolazione è stata di 20054499659923550137965608960 abitanti
# Nell'anno 605 la popolazione è stata di 22059949625915907350785425408 abitanti
# Nell'anno 606 la popolazione è stata di 24265944588507497206254665728 abitanti
# Nell'anno 607 la popolazione è stata di 26692539047358248246294085632 abitanti
# Nell'anno 608 la popolazione è stata di 29361792952094071751509540864 abitanti
# Nell'anno 609 la popolazione è stata di 32297972247303480685879099392 abitanti
# Nell'anno 610 la popolazione è stata di 35527769472033829634076311552 abitanti
# Nell'anno 611 la popolazione è stata di 39080546419237213477093244928 abitanti
# Nell'anno 612 la popolazione è stata di 42988601061160936144216522752 abitanti
# Nell'anno 613 la popolazione è stata di 47287461167277026240200966144 abitanti
# Nell'anno 614 la popolazione è stata di 52016207284004726225393156096 abitanti
# Nell'anno 615 la popolazione è stata di 57217828012405201486760378368 abitanti
# Nell'anno 616 la popolazione è stata di 62939610813645725153873625088 abitanti
# Nell'anno 617 la popolazione è stata di 69233571895010296789651685376 abitanti
# Nell'anno 618 la popolazione è stata di 76156929084511324709398249472 abitanti
# Nell'anno 619 la popolazione è stata di 83772621992962449263854354432 abitanti
# Nell'anno 620 la popolazione è stata di 92149884192258690671802580992 abitanti
# Nell'anno 621 la popolazione è stata di 101364872611484556220545630208 abitanti
# Nell'anno 622 la popolazione è stata di 111501359872633006564944379904 abitanti
# Nell'anno 623 la popolazione è stata di 122651495859896308980657422336 abitanti
# Nell'anno 624 la popolazione è stata di 134916645445885929323411537920 abitanti
# Nell'anno 625 la popolazione è stata di 148408309990474522255752691712 abitanti
# Nell'anno 626 la popolazione è stata di 163249140989521970962890752000 abitanti
# Nell'anno 627 la popolazione è stata di 179574055088474168059179827200 abitanti
# Nell'anno 628 la popolazione è stata di 197531460597321567272911765504 abitanti
# Nell'anno 629 la popolazione è stata di 217284606657053716963328524288 abitanti
# Nell'anno 630 la popolazione è stata di 239013067322759092178098585600 abitanti
# Nell'anno 631 la popolazione è stata di 262914374055035001395908444160 abitanti
# Nell'anno 632 la popolazione è stata di 289205811460538483943313244160 abitanti
# Nell'anno 633 la popolazione è stata di 318126392606592297153272479744 abitanti
# Nell'anno 634 la popolazione è stata di 349939031867251555016097398784 abitanti
# Nell'anno 635 la popolazione è stata di 384932935053976738665204809728 abitanti
# Nell'anno 636 la popolazione è stata di 423426228559374398457976455168 abitanti
# Nell'anno 637 la popolazione è stata di 465768851415311859414397353984 abitanti
# Nell'anno 638 la popolazione è stata di 512345736556843003134590582784 abitanti
# Nell'anno 639 la popolazione è stata di 563580310212527331595547312128 abitanti
# Nell'anno 640 la popolazione è stata di 619938341233780050681353207808 abitanti
# Nell'anno 641 la popolazione è stata di 681932175357158112044483870720 abitanti
# Nell'anno 642 la popolazione è stata di 750125392892873852880188080128 abitanti
# Nell'anno 643 la popolazione è stata di 825137932182161294463202230272 abitanti
# Nell'anno 644 la popolazione è stata di 907651725400377437983271288832 abitanti
# Nell'anno 645 la popolazione è stata di 998416897940415125486603075584 abitanti
# Nell'anno 646 la popolazione è stata di 1098258587734456595814016876544 abitanti
# Nell'anno 647 la popolazione è stata di 1208084446507902283542916235264 abitanti
# Nell'anno 648 la popolazione è stata di 1328892891158692469675961352192 abitanti
# Nell'anno 649 la popolazione è stata di 1461782180274561660348562145280 abitanti
# Nell'anno 650 la popolazione è stata di 1607960398302017685645930004480 abitanti
# Nell'anno 651 la popolazione è stata di 1768756438132219454210523004928 abitanti
# Nell'anno 652 la popolazione è stata di 1945632081945441455926570647552 abitanti
# Nell'anno 653 la popolazione è stata di 2140195290139985685961720725504 abitanti
# Nell'anno 654 la popolazione è stata di 2354214819153984423442878824448 abitanti
# Nell'anno 655 la popolazione è stata di 2589636301069382640607185338368 abitanti
# Nell'anno 656 la popolazione è stata di 2848599931176320679487922503680 abitanti
# Nell'anno 657 la popolazione è stata di 3133459924293952747436714754048 abitanti
# Nell'anno 658 la popolazione è stata di 3446805916723347797000404860928 abitanti
# Nell'anno 659 la popolazione è stata di 3791486508395682632995440689152 abitanti
# Nell'anno 660 la popolazione è stata di 4170635159235251121474966126592 abitanti
# Nell'anno 661 la popolazione è stata di 4587698675158776177327467397120 abitanti
# Nell'anno 662 la popolazione è stata di 5046468542674653795060214136832 abitanti
# Nell'anno 663 la popolazione è stata di 5551115396942119399746216919040 abitanti
# Nell'anno 664 la popolazione è stata di 6106226936636331902670792032256 abitanti
# Nell'anno 665 la popolazione è stata di 6716849630299964642577908498432 abitanti
# Nell'anno 666 la popolazione è stata di 7388534593329960769065727295488 abitanti
# Nell'anno 667 la popolazione è stata di 8127388052662956620792318656512 abitanti
# Nell'anno 668 la popolazione è stata di 8940126857929251945101578469376 abitanti
# Nell'anno 669 la popolazione è stata di 9834139543722177252201727000576 abitanti
# Nell'anno 670 la popolazione è stata di 10817553498094395652961843806208 abitanti
# Nell'anno 671 la popolazione è stata di 11899308847903834993078046818304 abitanti
# Nell'anno 672 la popolazione è stata di 13089239732694217816845907394560 abitanti
# Nell'anno 673 la popolazione è stata di 14398163705963639598530498134016 abitanti
# Nell'anno 674 la popolazione è stata di 15837980076560003108023585210368 abitanti
# Nell'anno 675 la popolazione è stata di 17421778084216004319545869205504 abitanti
# Nell'anno 676 la popolazione è stata di 19163955892637604075960512020480 abitanti
# Nell'anno 677 la popolazione è stata di 21080351481901365609456470065152 abitanti
# Nell'anno 678 la popolazione è stata di 23188386630091503521482005282816 abitanti
# Nell'anno 679 la popolazione è stata di 25507225293100655675070056759296 abitanti
# Nell'anno 680 la popolazione è stata di 28057947822410720792217099698176 abitanti
# Nell'anno 681 la popolazione è stata di 30863742604651792421078846930944 abitanti
# Nell'anno 682 la popolazione è stata di 33950116865116969861746880675840 abitanti
# Nell'anno 683 la popolazione è stata di 37345128551628666847921568743424 abitanti
# Nell'anno 684 la popolazione è stata di 41079641406791536234873502040064 abitanti
# Nell'anno 685 la popolazione è stata di 45187605547470688056921001295872 abitanti
# Nell'anno 686 la popolazione è stata di 49706366102217755961893175951360 abitanti
# Nell'anno 687 la popolazione è stata di 54677002712439527054482866176000 abitanti
# Nell'anno 688 la popolazione è stata di 60144702983683479759931152793600 abitanti
# Nell'anno 689 la popolazione è stata di 66159173282051823232324640702464 abitanti
# Nell'anno 690 la popolazione è stata di 72775090610257003754117253824512 abitanti
# Nell'anno 691 la popolazione è stata di 80052599671282707732408681103360 abitanti
# Nell'anno 692 la popolazione è stata di 88057859638410969498450294472704 abitanti
# Nell'anno 693 la popolazione è stata di 96863645602252073654054727712768 abitanti
# Nell'anno 694 la popolazione è stata di 106550010162477286423779753328640 abitanti
# Nell'anno 695 la popolazione è stata di 117205011178725006058958473920512 abitanti
# Nell'anno 696 la popolazione è stata di 128925512296597510267734023208960 abitanti
# Nell'anno 697 la popolazione è stata di 141818063526257252287308170788864 abitanti
# Nell'anno 698 la popolazione è stata di 155999869878882984721798391660544 abitanti
# ...
# Nell'anno 1908 la popolazione è stata di 18978997891840038594078045105394788546594520103777774365763640431170216217509101568 abitanti
# Nell'anno 1909 la popolazione è stata di 20876897681024044475481849652232252001280103640627852325125836164830173922030780416 abitanti
# Nell'anno 1910 la popolazione è stata di 22964587449126449597028701296221472068083491180181404398567030344827503341824114688 abitanti
# Nell'anno 1911 la popolazione è stata di 25261046194039094893730904765226616708229528885944928258888038661067409689801654272 abitanti
# Nell'anno 1912 la popolazione è stata di 27787150813443004046104661902366280945714793186794037664312537245416994644986691584 abitanti
# Nell'anno 1913 la popolazione è stata di 30565865894787303776716461413836914173610895329982674589815180406444382081895104512 abitanti
# Nell'anno 1914 la popolazione è stata di 33622452484266035502385440912752595324322739213962475730653919574117444345265127424 abitanti
# Nell'anno 1915 la popolazione è stata di 36984697732692641748618651719091834323456521837321790667433753785586436890152665088 abitanti
# Nell'anno 1916 la popolazione è stata di 40683167505961907945476516927299002355828305547526270256962960854688016661938700288 abitanti
# Nell'anno 1917 la popolazione è stata di 44751484256558097392026835262496912858060381751297363600802035813128194272952057856 abitanti
# Nell'anno 1918 la popolazione è stata di 49226632682213904435234852073682624677164911224464032597167797140383765589886238720 abitanti
# Nell'anno 1919 la popolazione è stata di 54149295950435294878758337281050887144881402346910435856884576854422142148874862592 abitanti
# Nell'anno 1920 la popolazione è stata di 59564225545478822344638170972857991259343411055129178919787202849321420280991580160 abitanti
# Nell'anno 1921 la popolazione è stata di 65520648100026701209108654676313816051900866283188262607122870316682002171139457024 abitanti
# Nell'anno 1922 la popolazione è stata di 72072712910029367286027520071349228457038689858562487822263493967264330222711865344 abitanti
# Nell'anno 1923 la popolazione è stata di 79279984201032299970638272005888182102690295791474135558918179982904891079441514496 abitanti
# Nell'anno 1924 la popolazione è stata di 87207982621135527271707432491413020846257816668658481751095555727138132077024641024 abitanti
# Nell'anno 1925 la popolazione è stata di 95928780883249075954886175667958353730831335282579728880633447918766073119185567744 abitanti
# Nell'anno 1926 la popolazione è stata di 105521658971573986246369459949818168570615977512800769132411234964699928541465149440 abitanti
# Nell'anno 1927 la popolazione è stata di 116073824868731378131019739157140036760923803509173177636366252826026801119709102080 abitanti
# Nell'anno 1928 la popolazione è stata di 127681207355604515944121713072854040437016183860090495400002878108629481231680012288 abitanti
# Nell'anno 1929 la popolazione è stata di 140449328091164959450549884234947506080613276140210342848859839157320685023764938752 abitanti
# Nell'anno 1930 la popolazione è stata di 154494260900281463483588872803634195088779129860120579224889149835224497857224507392 abitanti
# Nell'anno 1931 la popolazione è stata di 169943686990309604439958426653869655664254025442206502419949180310632451422224908288 abitanti
# Nell'anno 1932 la popolazione è stata di 186938055689340556795970269174064682830574901880537950570800771579523952233364324352 abitanti
# Nell'anno 1933 la popolazione è stata di 205631861258274620563551296236663089513736918174480947719024175499648091787783831552 abitanti
# Nell'anno 1934 la popolazione è stata di 226195047384102090707890426005521336865215136097818244582069919811784645297645289472 abitanti
# Nell'anno 1935 la popolazione è stata di 248814552122512294386690135175945511618333632303673934312848027284848613606687768576 abitanti
# Nell'anno 1936 la popolazione è stata di 273696007334763507649391148403156185979957943322262923561846176488989986305190395904 abitanti
# Nell'anno 1937 la popolazione è stata di 301065608068239847630351596383215886711147702846636946463173025121659992494265335808 abitanti
# Nell'anno 1938 la popolazione è stata di 331172168875063837785376089451665434315665490535226775836919212141940487964413919232 abitanti
# Nell'anno 1939 la popolazione è stata di 364289385762570216171924364966704018813829022184823318693182248848020040540133261312 abitanti
# Nell'anno 1940 la popolazione è stata di 400718324338827232397127468033246461761808906999379515835071589224707548373424537600 abitanti
# Nell'anno 1941 la popolazione è stata di 440790156772709928676893547685931313270974710679686793781434325606605822107156742144 abitanti
# Nell'anno 1942 la popolazione è stata di 484869172449980910760604235594268526731266146939803203704719989151037411876428316672 abitanti
# Nell'anno 1943 la popolazione è stata di 533356089694978969484728658572927625803974657210226715710618681017454175739738849280 abitanti
# Nell'anno 1944 la popolazione è stata di 586691698664476866433201524430220388384372122931249387281680549119199593313712734208 abitanti
# Nell'anno 1945 la popolazione è stata di 645360868530924531508564343152730591489197265608669787100133065998661567762195808256 abitanti
# Nell'anno 1946 la popolazione è stata di 709896955384016941523506110026979979170892852938127687990715296533611754772638990336 abitanti
# Nell'anno 1947 la popolazione è stata di 780886650922418592539942053588654305620757999000531378970355750122056960484126490624 abitanti
# Nell'anno 1948 la popolazione è stata di 858975316014660441009957592087263818316027764092732247412533556118033664091095040000 abitanti
# Nell'anno 1949 la popolazione è stata di 944872847616126539030846685597269789481660714541266819428075756810981992707425042432 abitanti
# Nell'anno 1950 la popolazione è stata di 1039360132377739106662102019274949425495378507532575345732021180362248252446614749184 abitanti
# Nell'anno 1951 la popolazione è stata di 1143296145615512952624440220040908860844080149438719263576076684301099123042611625984 abitanti
# Nell'anno 1952 la popolazione è stata di 1257625760177064183183012240883464239727651955535477573204537738633835080698208190464 abitanti
# Nell'anno 1953 la popolazione è stata di 1383388336194770644637228132412834335167641290320434408344422588562134558533805408256 abitanti
# Nell'anno 1954 la popolazione è stata di 1521727169814247665965036278213094097217181280121068771359433771353432044621409550336 abitanti
# Nell'anno 1955 la popolazione è stata di 1673899886795672389425625238593379835471675268901766570675946072423859279317774106624 abitanti
# Nell'anno 1956 la popolazione è stata di 1841289875475239671504102429893741490486066935023352305562971755731161177015327916032 abitanti
# Nell'anno 1957 la popolazione è stata di 2025418863022763552382683338001068296600225350062869380480406779174445355185307910144 abitanti
# Nell'anno 1958 la popolazione è stata di 2227960749325039735077293002037080440391351328143520007250723152832226011640733106176 abitanti
# Nell'anno 1959 la popolazione è stata di 2450756824257543665449107634799764812963262321726462930156364392050532643039030018048 abitanti
# Nell'anno 1960 la popolazione è stata di 2695832506683297902586274395956670279857916136204881989713707603060837998045603823616 abitanti
# Nell'anno 1961 la popolazione è stata di 2965415757351627434029413830906195279040362914436915721768491906977425979255505813504 abitanti
# Nell'anno 1962 la popolazione è stata di 3261957333086790004888696544232720121075502648954970982667616793415504698117950799872 abitanti
# Nell'anno 1963 la popolazione è stata di 3588153066395468919105736863773944790248604635387649925295516320627223228398193082368 abitanti
# Nell'anno 1964 la popolazione è stata di 3946968373035015681608566547828268254871792681232187684366774724495197641940683194368 abitanti
# Nell'anno 1965 la popolazione è stata di 4341665210338517336041252537493142423293420227818224608442314349074549345666304311296 abitanti
# Nell'anno 1966 la popolazione è stata di 4775831731372368810829889786596314636819417415211592602369959327592508461638276349952 abitanti
# Nell'anno 1967 la popolazione è stata di 5253414904509606037000196104784135472239152270584024485162403868871087065928315174912 abitanti
# Nell'anno 1968 la popolazione è stata di 5778756394960566554428386380380501676528619219179608778039782103628363832989593894912 abitanti
# Nell'anno 1969 la popolazione è stata di 6356632034456623123599395683536504501247032862634751500204898161861368276757000486912 abitanti
# Nell'anno 1970 la popolazione è stata di 6992295237902285349687505917008107608437287870435408494586525825917673164901147738112 abitanti
# Nell'anno 1971 la popolazione è stata di 7691524761692514229743573848237107741018809771330221966600627017028768239517473701888 abitanti
# Nell'anno 1972 la popolazione è stata di 8460677237861766170348907242353102572727380419240153097093862631510636700658537857024 abitanti
# Nell'anno 1973 la popolazione è stata di 9306744961647942614840139296824318144131221904238532095525524590402036491661286047744 abitanti
# Nell'anno 1974 la popolazione è stata di 10237419457812737566498787905563128702019930322364930550188974266480895657079837032448 abitanti
# Nell'anno 1975 la popolazione è stata di 11261161403594010978061349356591252200484130240750150982652423084609657464661609545728 abitanti
# Nell'anno 1976 la popolazione è stata di 12387277543953412593498460301542661478139232935602075014750838305849614848317087285248 abitanti
# Nell'anno 1977 la popolazione è stata di 13626005298348754370479282340989211683559845899939191450059095049213567970338112798720 abitanti
# Nell'anno 1978 la popolazione è stata di 14988605828183629807527210575088132851915830489933110595065004554134924767371924078592 abitanti
# Nell'anno 1979 la popolazione è stata di 16487466411001991407930662274484188650156241083521331164349710575471106211604271726592 abitanti
# Nell'anno 1980 la popolazione è stata di 18136213052102189168374459143819850028220692736468373790562887198940905800259854139392 abitanti
# Nell'anno 1981 la popolazione è stata di 19949834357312406704862635700089077544091589554710120679397381484757685347780994793472 abitanti
# Nell'anno 1982 la popolazione è stata di 21944817793043645994999629911985227811549576054776042257115325199156142850054249512960 abitanti
# Nell'anno 1983 la popolazione è stata di 24139299572348012319936179600824697451393499229510009595604100761668395925690730414080 abitanti
# Nell'anno 1984 la popolazione è stata di 26553229529582813551929797560907167196532849152461010555164510837835235518259803455488 abitanti
# Nell'anno 1985 la popolazione è stata di 29208552482541096287472046675110641403137306523112202100902756355696070102590628560896 abitanti
# Nell'anno 1986 la popolazione è stata di 32129407730795205226044616663565326799975450947720877065882134774227021596597269037056 abitanti
# Nell'anno 1987 la popolazione è stata di 35342348503874728509347617046147374453875340953303145752913937119804345821266685460480 abitanti
# Nell'anno 1988 la popolazione è stata di 38876583354262197909409205355480218181884943910120734102650844746591502822131242106880 abitanti
# Nell'anno 1989 la popolazione è stata di 42764241689688417700350125891028240000073438301132807512915929221250653104344366317568 abitanti
# Nell'anno 1990 la popolazione è stata di 47040665858657260850734407838243821487031954586651178754429316577453029447283647709184 abitanti
# Nell'anno 1991 la popolazione è stata di 51744732444522987625982483301124582379210736273018841874983145452236987908264434860032 abitanti
# Nell'anno 1992 la popolazione è stata di 56919205688975285008231462273124283130180637444915635572259665563383375666586033586176 abitanti
# Nell'anno 1993 la popolazione è stata di 62611126257872809368006800426098438982345183823191927658820248817489780135730102665216 abitanti
# Nell'anno 1994 la popolazione è stata di 68872238883660086163759672394370010419726184839295848954036890397006825051788578652160 abitanti
# Nell'anno 1995 la popolazione è stata di 75759462772026094780135639633807011461698803323225433849440579436707507556967436517376 abitanti
# Nell'anno 1996 la popolazione è stata di 83335409049228700117101395522849440147015166289332705763719254078146325215149645889536 abitanti
# Nell'anno 1997 la popolazione è stata di 91668949954151565987763727000796111700863165552050704869425796183729024639150076198912 abitanti
# Nell'anno 1998 la popolazione è stata di 100835844949566714304444483552199177949242447374825232415037609197638060908036015259648 abitanti
# Nell'anno 1999 la popolazione è stata di 110919429444523380213491854474968065796362002290687393695654192381092622868820237746176 abitanti
# Nell'anno 2000 la popolazione è stata di 122011372388975720995539578638690387349900547430566314045663200487356507220711951040512 abitanti
# Nell'anno 2001 la popolazione è stata di 134212509627873305518236960725574243467451154272268759862225670442787957235326748983296 abitanti
# Nell'anno 2002 la popolazione è stata di 147633760590660625027266501933229607918586890056254911926673882014448264698820665802752 abitanti
# Nell'anno 2003 la popolazione è stata di 162397136649726693051390229559003598658250268883500765080228447952202335298722111422464 abitanti
# Nell'anno 2004 la popolazione è stata di 178636850314699359595830713798678443550172950861040660607807703879267946763584633044992 abitanti
# Nell'anno 2005 la popolazione è stata di 196500535346169301076810862610997317852994935768765088629475652003503985569962475388928 abitanti
# Nell'anno 2006 la popolazione è stata di 216150588880786239466587565020773594560001464078072140433753983808318250321987791486976 abitanti
# Nell'anno 2007 la popolazione è stata di 237765647768864866173944860239076468989903955396689535457572971057304697419196260155392 abitanti
# Nell'anno 2008 la popolazione è stata di 261542212545751372116229117276562720706210765312029755866435390240117521616183712808960 abitanti
# Nell'anno 2009 la popolazione è stata di 287696433800326509327852029004218992776831841843232731453078929264129273777802084089856 abitanti
# Nell'anno 2010 la popolazione è stata di 316466077180359149217843077039738832158905646384315280676612466717923712895543534419968 abitanti
# Nell'anno 2011 la popolazione è stata di 348112684898395086225215694473516835166014970309228256587822424334953060705175404019712 abitanti
# Nell'anno 2012 la popolazione è stata di 382923953388234572762148954191064398891397708053669634403055955823211390255615428263936 abitanti
# Nell'anno 2013 la popolazione è stata di 421216348727058018995569694745268778884928099215795873921587195932914041021138213011456 abitanti
# Nell'anno 2014 la popolazione è stata di 463337983599763809852332509354893596877811529494134737391971560053586956863213276233728 abitanti
# Nell'anno 2015 la popolazione è stata di 509671781959740185316168682857931926617787992621927849170281538322636408419515224817664 abitanti
# Nell'anno 2016 la popolazione è stata di 560638960155714214890579706008627179175176171527361358009084047627518537521505505378304 abitanti
# Nell'anno 2017 la popolazione è stata di 616702856171285592208461057149881657510256270107134598122895030499796438233501023600640 abitanti
# Nell'anno 2018 la popolazione è stata di 678373141788414151429307162864869823261281897117848057935184533549776082056851125960704 abitanti
# Nell'anno 2019 la popolazione è stata di 746210455967255577615032034016258865483019466472873587650477342377372178522574996635648 abitanti
# Nell'anno 2020 la popolazione è stata di 820831501563981157462123547147688871822540172406642394259073787560346372894910012456960 abitanti
# Nell'anno 2021 la popolazione è stata di 902914651720379273208335901862457759004794189647306633684981166316381010184401013702656 abitanti
# Nell'anno 2022 la popolazione è stata di 993206116892417134272404562859291175531617330752592953522833150112308181642608566599680 abitanti
# Nell'anno 2023 la popolazione è stata di 1092526728581658847699645019145220293084779063827852248875116465123538999806869423259648 abitanti
# Dai dati statistici raccolti si può dedurre che nel corso degli anni ci sia stato un innalzamento demografico
# Simulazione calcolo statistico della natalità dal passato fino ad oggi completato corretamente

# %% [markdown]
# # CALCOLO DELLA DATA GIORNALIERA

# %%
#Comprendere come scrivere la data usando la libreria automatica datetime
import datetime#libreria automatica per la data
print("Ciao, questo programma permette di sapere la data, l'ora, i minuti e i secondi del momento preciso che si sta vivendo")
print("Quindi:")
oggi=datetime.datetime.today()#serve per ottenere la data e l'ora correnti
formattazionedata=oggi.strftime("%d/%m/%Y")#formattare la data nel formato "giorno/mese/anno"
formattazionetempo=oggi.strftime("%H:%M:%S")#formattare l'orario nel formato "ora:minuti:secondi"
print(f"Oggi è il giorno: {formattazionedata} e sono le ore: {formattazionetempo}")
# Out:
# Ciao, questo programma permette di sapere la data, l'ora, i minuti e i secondi del momento preciso che si sta vivendo
# Quindi:
# Oggi è il giorno: 10/11/2023 e sono le ore: 08:03:12

# %% [markdown]
# # IL CONVERTITORE DI UNITÀ DI MISURA UNIVERSALE

# %%
#Programma che permette di convertire diverse unità di misura con altre per sapere il risultato
print("Ciao, benvenuto nel convertitore di unità di misura universale!")
scelta=input("Quindi adesso scrivi quale unità di misura desideri convertire? (puoi scegliere soltanto tra queste opzioni: metri/piedi/chilogrammi/libbre/centimetri/pollici): ").lower()#converte tutto in minuscolo per semplificare il conteggio e non dover limitare l'utente a scrivere una determinata cosa
if scelta=="metri":#per ogni specificazione si una condizione diversa
    valore=float(input("Inserisci il specifico valore in metri: "))#vuol dire che l'input è un float cioè un numero con la virgola (si usa il punto) e non intero come è per l'int
    risultato=valore*3.2884#risultato finale del calcolo
    print(f"{valore} metri corrispondono a {risultato} piedi")
elif scelta=="piedi":
    valore=float(input("Inserisci il specifico valore in piedi: "))
    risultato=valore*3.8084
    print(f"{valore} piedi corrispondono a {risultato} metri")
elif scelta=="chilogrammi":
    valore=float(input("Inserisci il specifico valore in chilogrammi: "))
    risultato=valore*2.02462
    print(f"{valore} chilogrammi corrispondono a {risultato} libbre")
elif scelta=="libbre":
    valore=float(input("Inserisci il specifico valore in libbre: "))
    risultato=valore*2.20462
    print(f"{valore} libbre corrispondono a {risultato} chilogrammi")
elif scelta=="centimetri":
    valore=float(input("Inserisci il specifico valore in centimetri: "))
    risultato=valore*0.39370079
    print(f"{valore} centimetri corrispondono a {risultato} pollici")
elif scelta=="pollici":
    valore=float(input("Inserisci il specifico valore in pollici: "))
    risultato=valore*2.54
    print(f"{valore} pollici corrispondono a {risultato} centimetri")
else:
    print("Scelta non riconosciuta. Scegli tra una delle seguenti unità di misura riavviando prima il programma: metri/piedi/chilogrammi/libbre/centimetri/pollici")
# Out:
# Ciao, benvenuto nel convertitore di unità di misura universale!
# Quindi adesso scrivi quale unità di misura desideri convertire? (puoi scegliere soltanto tra queste opzioni: metri/piedi/chilogrammi/libbre/centimetri/pollici): centimetri
# Inserisci il specifico valore in centimetri: 20
# 20.0 centimetri corrispondono a 7.8740158000000005 pollici

# %% [markdown]
# # L'ALGORITMO PER CAPIRE LA SEQUENZA DI FIBONACCI

# %%
print("Ciao, attraverso questo programma puoi calcolare l'n-esimo numero di Fibonacci di qualsiasi numero che desideri sapere")
#Chiedere all'utente di inserire un numero n
n=int(input("Inserisci il numero di cui desideri calcolare l'n-esimo numero di Fibonacci: "))
a=0
b=1
if n<=0:
    print("Impossibile eseguire il calcolo perchè il numero deve essere maggiore di 0. Riavvia il programma per inserire un nuovo numero")
elif n==1:
    risultato=0
else:
    #Iniziallizare il contatore o iteratore
    for iterazione in range(n-1):
        c=a+b
        a=b
        b=c
    risultato=c
print(f"L'n-esimo numero di Fibonacci di {n} è {risultato}")
# Out:
# Ciao, attraverso questo programma puoi calcolare l'n-esimo numero di Fibonacci di qualsiasi numero che desideri sapere
# Inserisci il numero di cui desideri calcolare l'n-esimo numero di Fibonacci: 7
# L'n-esimo numero di Fibonacci di 7 è 13

# %% [markdown]
# # LE FUNZIONI CUSTOM

# %%
def fibonacci(n):#definizione di una funzione chiamata "fibonacci" con un parametro "n" (si può chiamare come dir si voglia)
    seriedifibonacci=[0,1]#inizializzazione della serie di Fibonacci con i primi due valori (0 e 1)
    while len(seriedifibonacci)<n:#utilizzo di un ciclo "while" per generare la serie fino a raggiungere la lunghezza 'n'
        seriedifibonacci.append(seriedifibonacci[-1]+seriedifibonacci[-2])#calcolo del prossimo valore della serie e lo si aggiunge alla lista
    return seriedifibonacci#la funzione restituisce la serie di Fibonacci generata

# %%
print("Ciao, attraverso questo programma puoi calcolare la sequenza di Fibonacci di qualsiasi numero che desideri sapere")
n=int(input("Quindi, inserisci il numero da cui desideri calcolare la sequenza di Fibonacci: "))
if n<=0:
    n=input("Inserisci un numero positivo: ")
else:
    risultato=fibonacci(n)#calcola la sequenza di Fibonacci del numero n e assegna il risultato a "risultato"
    print(f"Essendo che il numero è {n} allora la sequenza sarà: {risultato}")
# Out:
# Ciao, attraverso questo programma puoi calcolare la sequenza di Fibonacci di qualsiasi numero che desideri sapere
# Quindi, inserisci il numero da cui desideri calcolare la sequenza di Fibonacci: 7
# Essendo che il numero è 7 allora la sequenza sarà: [0, 1, 1, 2, 3, 5, 8]

# %% [markdown]
# # IL CALCOLATORE DI AREE GEOMETRICHE

# %%
import math
def calcoloareadelcerchio(raggio):#definizione della funzione
    return math.pi*(raggio**2)
def calcoloareatriangolo(base, altezza):#definizione della funzione
    return base*altezza/2  
def calcoloareadelrettangolo(base, altezza):#definizione della funzione
    return base*altezza
def calcolaareaquadrato(lato):
    return lato*lato  
print("Ciao, benvenuto nel calcolatore di aree geometriche!")
sceltaarea=input("Desideri calcolare l'area di un cerchio (c), del rettangolo (r), del triangolo (t) o del quadrato (q)? ")
if sceltaarea=="c":
    raggio=float(input("Inserisci il raggio del cerchio: "))  
    area=calcoloareadelcerchio(raggio)  
    print(f"L'area del cerchio è {area:.2f} m^2") 
elif sceltaarea=="r":
    base=float(input("Inserisci la base del rettangolo: "))  
    altezza=float(input("Inserisci l'altezza del rettangolo: "))  
    area=calcoloareadelrettangolo(base, altezza)  
    print(f"L'area del rettangolo è {area:.2f} m^2")  
elif sceltaarea=="t":
    base=float(input("Inserisci la base del triangolo: "))  
    altezza=float(input("Inserisci l'altezza del triangolo: "))  
    area=calcoloareatriangolo(base, altezza)  
    print(f"L'area del triangolo è {area:.2f} m^2")  
elif sceltaarea=="q":
    lato=float(input("Inserisci la misura del lato: "))  
    area=calcolaareaquadrato(lato)  
    print(f"L'area del quadrato è: {area:.2f} m^2")
else:
    print("Scelta non riconosciuta. Scegli tra una delle seguenti opzioni riavviando prima il programma: cerchio (c), del rettangolo (r), del triangolo (t) o del quadrato (q)")
# Out:
# Ciao, benvenuto nel calcolatore di aree geometriche!
# Desideri calcolare l'area di un cerchio (c), del rettangolo (r), del triangolo (t) o del quadrato (q)? c
# Inserisci il raggio del cerchio: 5
# L'area del cerchio è 78.54 m^2

# %% [markdown]
# # IL CALCOLATORE DI INTERESSI

# %%
def calcolainteresse(importoiniziale, tassointeresse, periodiinvestimento):
    importofinale=importoiniziale*(1+tassointeresse/100)**periodiinvestimento
    return importofinale
print("Ciao, benvenuto nel calcolatore di interessi!")
importoiniziale=float(input("Inserisci l'importo iniziale: "))
tassointeresse=float(input("Inserisci il tasso di interesse annuale(%): "))
periodiinvestimento=float(input("Inserisci il periodo di investimento (in anni): "))
importofinale=calcolainteresse(importoiniziale, tassointeresse, periodiinvestimento)
print(f"L'importo finale è {importofinale}")
# Out:
# Ciao, benvenuto nel calcolatore di interessi!
# Inserisci l'importo iniziale: 5
# Inserisci il tasso di interesse annuale(%): 20
# Inserisci il periodo di investimento (in anni): 7
# L'importo finale è 17.915903999999998

# %% [markdown]
# # I DIZIONARI E IL RISOLUTORE DEFINIZIONE DEI TASSI DI CAMBIO

# %%
#Definizione dei tassi di cambio
tassidicambio={#definizione del dizionario
    "dollari": 1.0,#key
    "euro": 0.85,#key
    "yen": 110.41,#key
    "lire italiane": 1936.27,#key
    "franco svizzero": 0.96#key
    #Aggiungere altre valute e tassi di cambio se è necessario
}
print("Ciao, con questo programma puoi vedere il tasso giornaliero delle seguenti valute: dollari, euro, yen, lire italiane e il franco svizzero")
#Chiedere all'utente l'importo delle varie valute per capire il cambio
importo=float(input("Inserisci l'importo che desideri convertire: "))
valutadipartenza=input("Inserisci la valuta di partenza (puoi scegliere solo: dollari, euro, yen, lire italiane e il franco svizzero): ").lower()#converte tutto in minuscolo per semplificare il conteggio e non dover limitare l'utente a scrivere una determinata cosa
valutadidestinazione=input("Inserisci la valuta di destinazione (puoi scegliere solo: dollari, euro, yen, lire italiane e il franco svizzero): ").lower()
if valutadipartenza in tassidicambio and valutadidestinazione in tassidicambio:
    tassodicambio=tassidicambio[valutadidestinazione]/tassidicambio[valutadipartenza]#Le parentesi quadre [ ] vengono utilizzate per accedere (richiamare) a un valore in un dizionario usando una keys (chiave), nonchè "valori" corrispondenti all'interno del dizionario
    importoconvertito=importo*tassodicambio
    print(f"{importo} {valutadipartenza} valgono e sono equivalenti a {importoconvertito:.2f} {valutadidestinazione}")# il simbolo 2f formatta "importoconvertito" come un numero decimale a virgola mobile con due cifre decimali (due perchè è 2f)
else:
    print("Valuta non supportata. Puoi inserire un'altra valuta riavviando prima il programma (puoi scegliere solo: dollari, euro, yen, lire italiane e il franco svizzero)")
# Out:
# Ciao, con questo programma puoi vedere il tasso giornaliero delle seguenti valute: dollari, euro, yen, lire italiane e il franco svizzero
# Inserisci l'importo che desideri convertire: 90
# Inserisci la valuta di partenza (puoi scegliere solo: dollari, euro, yen, lire italiane e il franco svizzero): euro
# Inserisci la valuta di destinazione (puoi scegliere solo: dollari, euro, yen, lire italiane e il franco svizzero): dollari
# 90.0 euro valgono e sono equivalenti a 105.88 dollari

# %% [markdown]
# # IL CONTALETTERE

# %%
#Programma che permette di contare quante lettere ci sono in una frase
print("Ciao, questo programma permettere di contare quante lettere ci sono in una frase")
#Chiedere all'utente di inserire una frase
frase=input("Quindi per prima cosa inserisci la frase che desideri che sia analizzata: ").lower()#converte tutto in minuscolo per semplificare il conteggio e non dover limitare l'utente a scrivere una determinata cosa
#Inizializzare una lista di lettere dell'alfabeto
alfabeto="abcdefghijklmnopqrstuvwxyz"
#Inizializzare un dizionario per tenere traccia del conteggio delle lettere
conteggiodellelettere={}
#Iterare attraverso ciascuna lettera dell'alfabeto
for lettera in alfabeto:
    #Contare quante volte appare la lettera nella frase
    conteggio=frase.count(lettera)#conta quante volte la "lettera" appare nella "frase".
    #Aggiungere la lettera e il conteggio al dizionario se la lettera appare almeno una volta
    if conteggio>0:
        conteggiodellelettere[lettera]=conteggio
#Stampare i conteggi delle singole lettere
for lettera, conteggio in conteggiodellelettere.items():
    print(f"{lettera}:{conteggio}")
#Calcolare il numero totale di lettere
numerototalelettere=sum(conteggiodellelettere.values())#serve a calcolare la somma dei valori all'interno del dizionario "conteggiodellelettere"
#"values()" restituisce una vista degli valori all'interno del dizionario 'conteggiodellelettere'.
#Stampare il conteggio totale
print(f"Il numero totale di lettere nella frase è {numerototalelettere}")
# Out:
# Ciao, questo programma permettere di contare quante lettere ci sono in una frase
# Quindi per prima cosa inserisci la frase che desideri che sia analizzata: cavallo
# a:2
# c:1
# l:2
# o:1
# v:1
# Il numero totale di lettere nella frase è 7

# %%
#Comprendere il comando items
conteggiodellelettere.items

# %%
#Comprendere il comando values
conteggiodellelettere.values

# %% [markdown]
# # I FUSI ORARI

# %%
from datetime import datetime
import pytz
print("Ciao, benvenuto nell'orologio mondiale!")
cittadisponibili = {
    "New York": "America/New_York",
    "Londra": "Europe/London",
    "Tokyo": "Asia/Tokyo",
    "Sydney": "Australia/Sydney",
    "Rio de Janeiro": "America/Sao_Paulo",
    "Mosca": "Europe/Moscow",
    "Pechino": "Asia/Shanghai",
    "Delhi": "Asia/Kolkata",
    "Berlino": "Europe/Berlin",
    "Città del Messico": "America/Mexico_City",
    "Johannesburg": "Africa/Johannesburg",
    "Dubai": "Asia/Dubai",
    "Singapore": "Asia/Singapore"
}
while True:
    print("\nCittà disponibili: ")#con il simbolo /n si va a capo dentro ad una stringa di testo
    for citta in cittadisponibili.keys():
        print(citta)
    sceltadellacitta = input("\nInserisci il nome della città per visualizzare l'ora (oppure scrivi 'esci' se desideri uscire dal programma): ").strip()
    if sceltadellacitta.lower() == "esci":
        print("Arrivederci, grazie per aver usato questo programma!")
        break
    elif sceltadellacitta in cittadisponibili:
        fusoorario = pytz.timezone(cittadisponibili[sceltadellacitta])
        orariocorrente = datetime.now(fusoorario)
        print(f"L'ora attuale a {sceltadellacitta} è {orariocorrente.strftime('%H:%M:%S')}\n")
    elif sceltadellacitta not in cittadisponibili:
        print("La città inserita non è nella lista. Per favore, prova di nuovo e controlla di aver scritto bene il nome della città.")
# Out:
# Ciao, benvenuto nell'orologio mondiale!
#
# Città disponibili:
# New York
# Londra
# Tokyo
# Sydney
# Rio de Janeiro
# Mosca
# Pechino
# Delhi
# Berlino
# Città del Messico
# Johannesburg
# Dubai
# Singapore
#
# Inserisci il nome della città per visualizzare l'ora (oppure scrivi 'esci' se desideri uscire dal programma): londra
# La città inserita non è nella lista. Per favore, prova di nuovo e controlla di aver scritto bene il nome della città.
#
# Città disponibili:
# New York
# Londra
# Tokyo
# Sydney
# Rio de Janeiro
# Mosca
# Pechino
# Delhi
# Berlino
# Città del Messico
# Johannesburg
# Dubai
# Singapore
#
# Inserisci il nome della città per visualizzare l'ora (oppure scrivi 'esci' se desideri uscire dal programma): Londra
# L'ora attuale a Londra è 07:09:44
#
#
# Città disponibili:
# New York
# Londra
# Tokyo
# Sydney
# Rio de Janeiro
# Mosca
# Pechino
# Delhi
# Berlino
# Città del Messico
# Johannesburg
# Dubai
# Singapore

# %% [markdown]
# # LA FUNZIONE MAIN

# %%
#Funzione principale che può avere qualsiasi nome (nome base: main)
def Angelo():#definisco Angelo
    print("Prova della funzione main,")
    prova=(input("Prova a scrivere qualcosa dentro questa casella: "))
    print(f"Vedi che va perchè infatti tu hai scritto: {prova}")
    print("Quindi abbiamo visto che la funzione Angelo funziona perchè ha richiamato tutto il codice del programma")
if __name__=="__main__":
    Angelo()
#Il programma chiama la funzione "Angelo()" soltanto se il file è eseguito come script principale.
# Out:
# Prova della funzione main,
# Prova a scrivere qualcosa dentro questa casella: ciao
# Vedi che va perchè infatti tu hai scritto: ciao
# Quindi abbiamo visto che la funzione Angelo funziona perchè ha richiamato tutto il codice del programma

# %% [markdown]
# # IL CALCOLO DELLA CALORIE

# %%
cibo_calorie = {
    "pizza": 285,
    "hamburger": 250,
    "insalata": 100,
    "yougurt" : 150,
}
def calorie_consumate(cibo, quantita):
    if cibo not in cibo_calorie.keys():
        print("Cibo non presente.")
        
    elif cibo in cibo_calorie.keys():
        calorie_per_100g = cibo_calorie[cibo]
        calorie_totali = (calorie_per_100g / 100) * quantita
        return calorie_totali
        
def main():
    cibo_consumato = []  
    while True:  
        print("Menu: ")
        print("1. Aggiungi cibo consumato")
        print("2. Calcola calorie totali")
        print("3. Esci")
        scelta = input("Scegli una opzione: ")
        if scelta == "1":
            print("\nEcco l'elenco di cibi disponibili:")
            for key, value in cibo_calorie.items():
                print(key, value)
            cibo = input("Inserisci il cibo consumato: ").lower()
            quantita = float(input("Inserisci la quantita in grammi: "))
            cibo_consumato.append((cibo, quantita))
        elif scelta == "2":
            calorie_totali = sum(calorie_consumate(cibo, quantita) for cibo, quantita in cibo_consumato)
            print(f"Hai consumato un totale di {calorie_totali} calorie.")
        elif scelta == "3":
            print("Arrivederci!")
            break
        else:
            print("Scelta non valida. Riprova.")
if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Aggiungi cibo consumato
# 2. Calcola calorie totali
# 3. Esci
# Scegli una opzione: 1
#
# Ecco l'elenco di cibi disponibili:
# pizza 285
# hamburger 250
# insalata 100
# yougurt 150
# Inserisci il cibo consumato: pizza
# Inserisci la quantita in grammi: 500
# Menu:
# 1. Aggiungi cibo consumato
# 2. Calcola calorie totali
# 3. Esci
# Scegli una opzione: 2
# Hai consumato un totale di 1425.0 calorie.
# Menu:
# 1. Aggiungi cibo consumato
# 2. Calcola calorie totali
# 3. Esci
# Scegli una opzione: 3
# Arrivederci!

# %% [markdown]
# # GENERATORE DI PERSONAGGI FANTASY

# %%
import random
speci=["Umano", "Elfo", "Nano", "Orco"]
classi=["Guerriero", "Mago", "Ladro", "Chierico"]
armi=["Spada", "Arco", "Bastone", "Pugnale"]
abilita=["Fuoco", "Gelo", "Cura", "Invisibilità", "Forza", "Velocità"]


specie=random.choice(speci)
classe=random.choice(classi)
arma=random.choice(armi)
abilita_scelte = random.sample(abilita, random.randint(1, 3))


print("Personaggio fantasy generato: ")
print(f"Specie: {specie}")
print(f"Classe: {classe}")
print(f"Arma: {arma}")
print(f"Abilità: {', '.join(abilita_scelte)}")
# Out:
# Personaggio fantasy generato:
# Specie: Nano
# Classe: Chierico
# Arma: Bastone
# Abilità: Forza, Gelo, Velocità

# %%
import random

physical_traits=["Capelli neri", "Capelli biondi", "Occhi azzurri", "Alto", "Basso", "Barba lunga"]
personality_traits=["Gentile", "Arrogante", "Timido", "Audace", "Curioso"]
backgrounds=["Contadino", "Nobile", "Guerriero", "Mercante", "Mago"]
motivations=["Vendetta", "Ricchezza", "Potere", "Amore", "Scoperta"]

def genera_personaggio():
    nome=input("Inserisci il nome del personaggio: ")
    aspetto_fisico=random.choice(physical_traits)
    aspetto_personale=random.choice(personality_traits)
    sfondo=random.choice(backgrounds)
    motivazione=random.choice(motivations)

    descrizione=(
        f"Nome: {nome}\n"
        f"Aspetto fisico: {aspetto_fisico}\n"
        f"Aspetto personale: {aspetto_personale}\n"
        f"Sfondo: {sfondo}\n"
        f"Motivazione: {motivazione}"
    )
    return descrizione
print("Personaggio fantasy generato: ")
print(genera_personaggio())
# Out:
# Personaggio fantasy generato:
# Inserisci il nome del personaggio: Costanzo
# Nome: Costanzo
# Aspetto fisico: Occhi azzurri
# Aspetto personale: Audace
# Sfondo: Guerriero
# Motivazione: Amore
